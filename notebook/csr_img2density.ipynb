# %%
import os
import random

import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.transforms import Compose, ToTensor, Normalize, ToPILImage
from PIL import Image
import cv2

from utils import LabelNormalize, DeNormalize
# Out:
# /home/ma-user/anaconda3/envs/PyTorch-1.11.0/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# ### Dataset定义
# 数据集与上次实验中使用AlexNet预测密度图的数据集一致。
#
# 注意：这里图像和密度图的尺寸并未保持一致。出于对模型在云平台上稳定训练的考虑，下面的模型部分没有使用upsample操作，故应在数据载入时进行相应处理，保证模型输出尺寸与密度图尺寸一致。具体地，密度图下采样为原尺寸的1/8，同时乘64（8*8）以保持总人数不变。

# %%
class SHHB(Dataset):
    def __init__(self, data_path, mode='train', main_transform=None, img_transform=None, gt_transform=None):
        self.img_path = data_path + '/' + mode + '_data/img'
        self.gt_path = data_path + '/' + mode + '_data/den'
        self.data_files = [filename for filename in os.listdir(self.img_path) \
                           if os.path.isfile(os.path.join(self.img_path,filename))]
        self.num_samples = len(self.data_files) 
        self.main_transform=main_transform  
        self.img_transform = img_transform
        self.gt_transform = gt_transform     
    
    def __getitem__(self, index):
        fname = self.data_files[index]
        img, den = self._read_image_and_gt(fname)
        if self.main_transform is not None:
            img, den = self.main_transform(img, den) 
        if self.img_transform is not None:
            img = self.img_transform(img)         
        if self.gt_transform is not None:
            den = self.gt_transform(den)               
        return img, den

    def __len__(self):
        return self.num_samples

    def _read_image_and_gt(self, fname):
        img = Image.open(os.path.join(self.img_path, fname))
        if img.mode == 'L':
            img = img.convert('RGB')
        den = pd.read_csv(os.path.join(self.gt_path, os.path.splitext(fname)[0] + '.csv'), sep=',', header=None).values
        den = den.astype(np.float32, copy=False)    
        # Precomputed densities are already at 1/8 resolution (coordinate-scaling approach).
        # Just scale by 64 to preserve the total person count.
        den = den * 64
        return img, den

    def get_num_samples(self):
        return self.num_samples

# %% [markdown]
# ### 实现训练、验证和测试所用的DataLoader
#
# 与Alex实验代码相比，这里没有使用随机裁剪和反转来增强训练数据。

# %%
def get_data_loader(dataset_path, batch_size=8, mode='train'):
    assert mode == 'train' or mode == 'test'
    mean_std = ([0.485, 0.456, 0.406], 
                [0.229, 0.224, 0.225])
    log_para = 100
    img_transform = Compose([
        ToTensor(),
        Normalize(*mean_std)
    ])
    gt_transform = Compose([
        LabelNormalize(log_para)
    ])
    restore_transform = Compose([
        DeNormalize(*mean_std),
        ToPILImage()
    ])
    main_transform = None
    dataset = None
    data_loader = None
    if mode == 'train':
        dataset = SHHB(dataset_path, 
                    'train', 
                    main_transform=main_transform, 
                    img_transform=img_transform, 
                    gt_transform=gt_transform)
        train_size = int(0.8 * len(dataset))
        val_size = len(dataset) - train_size
        train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
        train_data_loader = DataLoader(train_dataset, 
                                batch_size=batch_size, 
                                num_workers=8, 
                                shuffle=True, 
                                drop_last=True)
        val_data_loader = DataLoader(val_dataset, 
                                batch_size=batch_size, 
                                num_workers=8, 
                                shuffle=True, 
                                drop_last=True)
        return train_data_loader, val_data_loader, log_para, restore_transform
    elif mode == 'test':
        main_transform = None
        dataset = SHHB(dataset_path, 
                    'test', 
                    main_transform=main_transform, 
                    img_transform=img_transform, 
                    gt_transform=gt_transform)
        data_loader = DataLoader(dataset, 
                                batch_size=batch_size, 
                                num_workers=8, 
                                shuffle=True, 
                                drop_last=True)
        return data_loader, log_para, restore_transform

# %% [markdown]
# ### DataLoader验证
#
# 密度图尺寸为原图像尺寸1/8，符合预期。

# %%
chk_train_loader, chk_val_loader, _, _ = get_data_loader('./dataset', 4, 'train')
train_img, train_gt = next(iter(chk_train_loader))
print(train_img.shape, train_gt.shape)
val_img, val_gt = next(iter(chk_val_loader))
print(val_img.shape, val_gt.shape)
chk_test_loader, _, _ = get_data_loader('./dataset', 1, 'test')
test_img, test_gt  = next(iter(chk_test_loader))
print(test_img.shape, test_gt.shape)
# Out:
# torch.Size([4, 3, 768, 1024]) torch.Size([4, 96, 128])
# torch.Size([4, 3, 768, 1024]) torch.Size([4, 96, 128])
# torch.Size([1, 3, 768, 1024]) torch.Size([1, 96, 128])

# %% [markdown]
# ### Density Map 可视化
#
# 下面直接从 `den` 目录里读取几个 ground-truth density map，看看生成结果是否正常。

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

candidate_dirs = [
    Path('datasets/Tenebrio/test/den'),
    Path('../datasets/Tenebrio/test/den'),
    Path('../../datasets/Tenebrio/test/den'),
]
sample_den_dir = next((path for path in candidate_dirs if path.exists()), candidate_dirs[0])
sample_files = sorted(sample_den_dir.glob('*.csv'))[:3]

if not sample_files:
    print(f'No density maps found in {sample_den_dir.resolve()}')
else:
    fig, axes = plt.subplots(1, len(sample_files), figsize=(5 * len(sample_files), 4))
    if len(sample_files) == 1:
        axes = [axes]

    for ax, den_file in zip(axes, sample_files):
        den = np.loadtxt(den_file, delimiter=',', dtype=np.float32)
        ax.imshow(den, cmap='jet', interpolation='nearest')
        ax.set_title(f'{den_file.stem}\ncount={den.sum():.2f}')
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Recomputed Tenebrio Density Maps Examples
#
# Showing examples of recomputed ground truth density maps using the coordinate-scaling approach (1/8 resolution with Gaussian blur, sigma=15/8).

# %%
from pathlib import Path
import os
import random

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Set up Tenebrio dataset paths (use absolute paths)
script_dir = Path(__file__).resolve().parent if '__file__' in dir() else Path.cwd()
repo_root = script_dir.parent if 'notebook' in script_dir.parts else Path.cwd()
tenebrio_dir = repo_root / 'datasets' / 'Tenebrio'

splits_to_check = ['train', 'val', 'test']

# Collect all available density map files
all_den_files = []
for split in splits_to_check:
    den_dir = tenebrio_dir / split / 'den'
    if den_dir.exists():
        den_files = sorted(den_dir.glob('*.csv'))
        all_den_files.extend([(split, f) for f in den_files])

print(f"Tenebrio directory: {tenebrio_dir}")
print(f"Total density map files found: {len(all_den_files)}")
print(f"  Train: {len([f for s, f in all_den_files if s == 'train'])}")
print(f"  Val: {len([f for s, f in all_den_files if s == 'val'])}")
print(f"  Test: {len([f for s, f in all_den_files if s == 'test'])}")

# Display a couple of random examples with their corresponding images
if all_den_files:
    # Select 2 random examples
    selected = random.sample(all_den_files, min(2, len(all_den_files)))
    
    fig, axes = plt.subplots(len(selected), 3, figsize=(15, 5 * len(selected)))
    if len(selected) == 1:
        axes = axes.reshape(1, -1)
    
    for row_idx, (split, den_file) in enumerate(selected):
        # Load density map
        den = np.loadtxt(den_file, delimiter=',', dtype=np.float32)
        
        # Load corresponding image
        img_file = tenebrio_dir / split / 'img' / f'{den_file.stem}.png'
        img = Image.open(img_file)
        
        # Normalize density for visualization
        den_norm = (den - den.min()) / (den.max() - den.min() + 1e-8)
        
        # Row 1: Image
        axes[row_idx, 0].imshow(img, cmap='gray')
        axes[row_idx, 0].set_title(f'{split.upper()}: {den_file.stem}\n(Image)')
        axes[row_idx, 0].axis('off')
        
        # Row 2: Density map (raw)
        axes[row_idx, 1].imshow(den, cmap='jet', interpolation='nearest')
        axes[row_idx, 1].set_title(f'Density Map (Raw)\nCount: {den.sum():.1f}\nShape: {den.shape}')
        axes[row_idx, 1].axis('off')
        
        # Row 3: Normalized density for better visualization
        axes[row_idx, 2].imshow(den_norm, cmap='hot', interpolation='nearest')
        axes[row_idx, 2].set_title(f'Density Map (Normalized)\nMax: {den.max():.4f}\nMin: {den.min():.4f}')
        axes[row_idx, 2].axis('off')
    
    plt.tight_layout()
    plt.show()
# Out:
# Tenebrio directory: /home/umrobotics/C-3-Framework/datasets/Tenebrio
# Total density map files found: 1120
#   Train: 840
#   Val: 168
#   Test: 112

# %% [markdown]
# **任务. 实现 CSRNet 类中的 _make_layers 方法，使用_make_layers 方法补全模型的 frontend 和 backend 部分以及前向传播流程。**
#
# **具体要求：**
#
# _make_layers 方法根据提供的配置列表创建神经网络的一系列层。这个配置列表 cfg 包含整数和字符 'M'：整数代表需要创建的卷积层的输出通道数，而 'M' 代表一个最大池化层。此方法还应能够处理可选参数，以支持不同的网络配置需求，包括输入通道数 in_channels，是否使用批量归一化 batch_norm，以及是否应用空洞卷积 dilation。
#
# forward 方法即一般的前向传播。
#
# 另外，本次实验的预训练权重是从当前所在目录读取的，注意从OBS中上传至当前目录。
#
# **_make_layers 方法实现提示：**
# 1. 初始化层列表： 开始时，创建一个空列表 layers 以收集所有生成的层。
# 2. 遍历配置列表： 对 cfg 进行遍历，根据遍历到的元素类型（整数或 'M'）来决定添加什么类型的层。
# 3. 卷积层： 如果元素是整数，你需要添加一个 nn.Conv2d 层。该层的输入通道数为 in_channels（这个值会随着新层的添加而更新），输出通道数为当前元素值。确保考虑 dilation 参数，如果 dilation 为 True，则应该使用不同的 dilation 和 padding 值来创建卷积层。
# 4. 最大池化层： 如果元素是 'M'，则添加一个 nn.MaxPool2d 层，通常使用 2x2 的池化窗口和步长。
# 5. 批量归一化和激活： 对于每个卷积层，根据 batch_norm 参数决定是否添加 nn.BatchNorm2d 层。不论是否使用批量归一化，都应该在每个卷积层后添加 nn.ReLU 作为激活函数。
# 6. 更新输入通道数： 每添加一个卷积层后，更新 in_channels 的值为该层的输出通道数，以便为下一个卷积层正确设置输入通道数。
# 7. 返回层序列： 使用 nn.Sequential 将列表 layers 中的所有层转换成一个序列，并返回这个序列。
# 8. 关于模型配置细节，可以参考CSRNet论文Table3。

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models


class CSRNet(nn.Module):
    def __init__(self):
        super(CSRNet, self).__init__()
        self.frontend_feat = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512]
        self.backend_feat  = [512, 512, 512, 256, 128, 64]
        self.frontend = self._make_layers(self.frontend_feat)
        self.backend = self._make_layers(self.backend_feat, in_channels=512, dilation=True)
        self.output_layer = nn.Conv2d(64, 1, kernel_size=1)
        mod = models.vgg16(pretrained=False)
        mod.load_state_dict(torch.load('./vgg16-397923af.pth'))
        self.frontend.load_state_dict(mod.features[0:23].state_dict())

    def forward(self,x):
        x = self.frontend(x)
        x = self.backend(x)
        x = self.output_layer(x)
        return x 
    
    def _make_layers(self, cfg, in_channels=3, batch_norm=False, dilation=False):
        if dilation:
            d_rate = 2
        else:
            d_rate = 1
        layers = []
        for v in cfg:
            if v == 'M':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=d_rate, dilation=d_rate)
                if batch_norm:
                    layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU()]
                else:
                    layers += [conv2d, nn.ReLU()]
                in_channels = v
        return nn.Sequential(*layers)

# %% [markdown]
# ### 模型验证

# %%
model = CSRNet()
ret = model(torch.randn(4, 3, 64, 64))
print(ret.shape)
# Out:
# torch.Size([4, 1, 8, 8])

# %%
def train(net, train_loader, device, criterion, optimizer, epoch):
    net.train()
    total_loss = 0
    for inputs, gt in train_loader:
        inputs, gt = inputs.to(device), gt.to(device)
        pred_map = net(inputs).squeeze()
        optimizer.zero_grad()
        loss = criterion(pred_map, gt)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
    avg_loss = total_loss / len(train_loader)
    return avg_loss

def val(net, val_loader, device, criterion, epoch, log_para):
    net.eval()
    total_loss = 0
    gt_cnt_lis = []
    pred_cnt_lis = []
    with torch.no_grad():
        for inputs, gt in val_loader:
            inputs, gt = inputs.to(device), gt.to(device)
            pred_map = net(inputs).squeeze()

            loss = criterion(pred_map, gt)
            total_loss += loss.item()
            gt = gt.data.cpu().numpy()
            pred_map = pred_map.data.cpu().numpy()
            for i in range(gt.shape[0]):
                gt_cnt = np.sum(gt[i]) / log_para
                pred_cnt = np.sum(pred_map[i]) / log_para
                gt_cnt_lis.append(float(gt_cnt))
                pred_cnt_lis.append(float(pred_cnt))

    avg_loss = total_loss / len(val_loader)
    y_true = np.array(gt_cnt_lis)
    y_pred = np.array(pred_cnt_lis)
    rmse = np.sqrt(np.mean((y_true - y_pred)**2)) 
    mae = np.mean(np.abs(y_true - y_pred))
    return avg_loss, rmse, mae

# %% [markdown]
# ### 昇腾迁移

# %%
import torch_npu
print(torch.cuda.is_available())

from torch_npu.contrib import transfer_to_npu
print(torch.cuda.is_available())
print(torch.npu.is_available())
# Out:
# Warning : ASCEND_HOME_PATH environment variable is not set.
# False
# True
# True
# /home/ma-user/anaconda3/envs/PyTorch-1.11.0/lib/python3.7/site-packages/torch_npu/contrib/transfer_to_npu.py:167: ImportWarning:
#     *************************************************************************************************************
#     The torch.Tensor.cuda and torch.nn.Module.cuda are replaced with torch.Tensor.npu and torch.nn.Module.npu now..
#     The torch.cuda.DoubleTensor is replaced with torch.npu.FloatTensor cause the double type is not supported now..
#     The backend in torch.distributed.init_process_group set to hccl now..
#     The torch.cuda.* and torch.cuda.amp.* are replaced with torch.npu.* and torch.npu.amp.* now..
#     The device parameters have been replaced with npu in the function below:
#     torch.logspace, torch.randint, torch.hann_window, torch.rand, torch.full_like, torch.ones_like, torch.rand_like, torch.randperm, torch.arange, torch.frombuffer, torch.normal, torch._empty_per_channel_affine_quantized, torch.empty_strided, torch.empty_like, torch.scalar_tensor, torch.tril_indices, torch.bartlett_window, torch.ones, torch.sparse_coo_tensor, torch.randn, torch.kaiser_window, torch.tensor, torch.triu_indices, torch.as_tensor, torch.zeros, torch.randint_like, torch.full, torch.eye, torch._sparse_csr_tensor_unsafe, torch.empty, torch._sparse_coo_tensor_unsafe, torch.blackman_window, torch.zeros_like, torch.range, torch.sparse_csr_tensor, torch.randn_like, torch.from_file, torch._cudnn_init_dropout_state, torch._empty_affine_quantized, torch.linspace, torch.hamming_window, torch.empty_quantized, torch._pin_memory, torch.autocast, torch.Tensor.new_empty, torch.Tensor.new_empty_strided, torch.Tensor.new_full, torch.Tensor.new_ones, torch.Tensor.new_tensor, torch.Tensor.new_zeros, torch.Tensor.to, torch.nn.Module.to, torch.nn.Module.to_empty
#     *************************************************************************************************************
#
#   warnings.warn(msg, ImportWarning)

# %% [markdown]
# ### 模型训练

# %%
# %%time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_loader, val_loader, log_para, _ = get_data_loader('./dataset', batch_size=8, mode='train')
net = CSRNet().to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(net.parameters(), lr=1e-5, momentum=0.95, weight_decay=5e-4)

# 可适当减小训练轮数，根据经验来说，200轮上下即可得到相对不错的结果
num_epochs = 400
for epoch in range(num_epochs):
    best_val_rmse = np.inf
    best_val_mae = np.inf
    train_loss = train(net, train_loader, device, criterion, optimizer, epoch)
    val_loss, val_rmse, val_mae = val(net, val_loader, device, criterion, epoch, log_para)
    print(f'Epoch {epoch + 1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, \
          Val RMSE: {val_rmse:.4f}, Val MAE: {val_mae:.4f}')
    if val_rmse < best_val_rmse or val_mae < best_val_mae:
        best_val_rmse = np.min([best_val_rmse, val_rmse])
        best_val_mae = np.min([best_val_mae, val_mae])
        torch.save(net.state_dict(), f'{net.__class__.__name__}_best_model.pth')
# Out:
# Epoch 1, Train Loss: 54.8156, Val Loss: 56.0610,           Val RMSE: 166.4308, Val MAE: 137.7492
# Epoch 2, Train Loss: 54.7776, Val Loss: 56.0163,           Val RMSE: 164.4186, Val MAE: 135.3175
# Epoch 3, Train Loss: 54.7343, Val Loss: 55.9718,           Val RMSE: 162.3902, Val MAE: 132.8519
# Epoch 4, Train Loss: 54.6925, Val Loss: 55.9286,           Val RMSE: 160.3998, Val MAE: 130.4183
# Epoch 5, Train Loss: 54.6522, Val Loss: 55.8870,           Val RMSE: 158.4626, Val MAE: 128.0358
# Epoch 6, Train Loss: 54.6136, Val Loss: 55.8462,           Val RMSE: 156.5414, Val MAE: 125.6591
# Epoch 7, Train Loss: 54.5750, Val Loss: 55.8080,           Val RMSE: 154.7307, Val MAE: 123.4060
# Epoch 8, Train Loss: 54.5394, Val Loss: 55.7678,           Val RMSE: 152.8089, Val MAE: 120.9999
# Epoch 9, Train Loss: 54.5022, Val Loss: 55.7301,           Val RMSE: 150.9932, Val MAE: 118.7129
# Epoch 10, Train Loss: 54.4665, Val Loss: 55.6921,           Val RMSE: 149.1523, Val MAE: 116.3800
# Epoch 11, Train Loss: 54.4306, Val Loss: 55.6542,           Val RMSE: 147.3105, Val MAE: 114.0693
# Epoch 12, Train Loss: 54.3948, Val Loss: 55.6152,           Val RMSE: 145.4132, Val MAE: 111.7486
# Epoch 13, Train Loss: 54.3582, Val Loss: 55.5745,           Val RMSE: 143.4375, Val MAE: 109.3202
# Epoch 14, Train Loss: 54.3192, Val Loss: 55.5329,           Val RMSE: 141.4332, Val MAE: 106.8938
# Epoch 15, Train Loss: 54.2783, Val Loss: 55.4873,           Val RMSE: 139.2648, Val MAE: 104.2741
# Epoch 16, Train Loss: 54.2329, Val Loss: 55.4356,           Val RMSE: 136.8553, Val MAE: 101.5260
# Epoch 17, Train Loss: 54.1812, Val Loss: 55.3710,           Val RMSE: 133.9231, Val MAE: 98.4586
# Epoch 18, Train Loss: 54.1141, Val Loss: 55.2901,           Val RMSE: 130.3970, Val MAE: 95.1179
# Epoch 19, Train Loss: 54.0243, Val Loss: 55.1727,           Val RMSE: 125.5175, Val MAE: 90.8587
# Epoch 20, Train Loss: 53.8855, Val Loss: 54.9787,           Val RMSE: 117.9293, Val MAE: 84.9415
# Epoch 21, Train Loss: 53.6374, Val Loss: 54.5818,           Val RMSE: 103.8522, Val MAE: 74.9007
# Epoch 22, Train Loss: 53.0837, Val Loss: 53.6504,           Val RMSE: 81.7519, Val MAE: 65.8338
# Epoch 23, Train Loss: 51.9069, Val Loss: 52.0936,           Val RMSE: 126.0854, Val MAE: 117.3865
# Epoch 24, Train Loss: 50.0517, Val Loss: 49.7382,           Val RMSE: 94.2442, Val MAE: 87.2479
# Epoch 25, Train Loss: 47.8340, Val Loss: 47.8055,           Val RMSE: 71.2320, Val MAE: 66.0107
# Epoch 26, Train Loss: 46.0622, Val Loss: 45.9146,           Val RMSE: 94.4854, Val MAE: 87.7168
# Epoch 27, Train Loss: 44.2554, Val Loss: 45.1213,           Val RMSE: 44.9434, Val MAE: 39.7120
# Epoch 28, Train Loss: 43.3679, Val Loss: 44.1225,           Val RMSE: 53.3489, Val MAE: 48.1391
# Epoch 29, Train Loss: 42.2067, Val Loss: 43.6895,           Val RMSE: 44.5072, Val MAE: 40.0841
# Epoch 30, Train Loss: 41.6428, Val Loss: 43.4115,           Val RMSE: 53.6465, Val MAE: 49.6335
# Epoch 31, Train Loss: 41.2467, Val Loss: 42.9335,           Val RMSE: 40.4341, Val MAE: 36.0303
# Epoch 32, Train Loss: 41.2701, Val Loss: 42.8622,           Val RMSE: 36.2690, Val MAE: 29.9204
# Epoch 33, Train Loss: 40.3419, Val Loss: 42.4812,           Val RMSE: 51.8241, Val MAE: 48.4068
# Epoch 34, Train Loss: 39.8843, Val Loss: 44.0670,           Val RMSE: 84.0038, Val MAE: 78.1449
# Epoch 35, Train Loss: 40.2232, Val Loss: 41.6479,           Val RMSE: 37.1313, Val MAE: 33.0837
# Epoch 36, Train Loss: 39.1692, Val Loss: 41.3703,           Val RMSE: 35.8790, Val MAE: 32.0230
# Epoch 37, Train Loss: 39.0128, Val Loss: 41.3536,           Val RMSE: 34.9194, Val MAE: 26.9729
# Epoch 38, Train Loss: 38.5111, Val Loss: 40.7969,           Val RMSE: 32.6541, Val MAE: 28.4061
# Epoch 39, Train Loss: 37.9783, Val Loss: 40.4740,           Val RMSE: 31.3389, Val MAE: 26.6816
# Epoch 40, Train Loss: 37.6296, Val Loss: 40.0570,           Val RMSE: 31.1957, Val MAE: 27.4463
# Epoch 41, Train Loss: 37.3508, Val Loss: 40.0799,           Val RMSE: 34.0148, Val MAE: 24.2124
# Epoch 42, Train Loss: 37.0120, Val Loss: 39.3638,           Val RMSE: 29.1713, Val MAE: 25.3970
# Epoch 43, Train Loss: 36.6566, Val Loss: 39.5816,           Val RMSE: 42.8668, Val MAE: 28.8601
# Epoch 44, Train Loss: 37.2309, Val Loss: 38.4005,           Val RMSE: 34.5492, Val MAE: 31.5164
# Epoch 45, Train Loss: 35.9839, Val Loss: 38.0808,           Val RMSE: 44.9457, Val MAE: 40.9044
# Epoch 46, Train Loss: 35.5252, Val Loss: 37.4963,           Val RMSE: 34.9001, Val MAE: 31.0185
# Epoch 47, Train Loss: 35.0174, Val Loss: 37.4049,           Val RMSE: 43.6045, Val MAE: 29.3933
# Epoch 48, Train Loss: 34.1387, Val Loss: 36.0856,           Val RMSE: 26.8689, Val MAE: 21.8919
# Epoch 49, Train Loss: 34.1355, Val Loss: 37.9150,           Val RMSE: 69.5819, Val MAE: 50.6657
# Epoch 50, Train Loss: 34.7590, Val Loss: 35.4768,           Val RMSE: 39.0555, Val MAE: 34.3141
# Epoch 51, Train Loss: 32.8007, Val Loss: 35.1930,           Val RMSE: 40.6323, Val MAE: 27.1137
# Epoch 52, Train Loss: 31.7346, Val Loss: 33.9571,           Val RMSE: 24.9131, Val MAE: 20.1525
# Epoch 53, Train Loss: 31.0414, Val Loss: 33.3962,           Val RMSE: 24.7679, Val MAE: 19.1963
# Epoch 54, Train Loss: 30.3553, Val Loss: 32.5871,           Val RMSE: 22.0780, Val MAE: 16.1891
# Epoch 55, Train Loss: 29.6849, Val Loss: 32.0748,           Val RMSE: 26.6317, Val MAE: 17.8949
# Epoch 56, Train Loss: 29.3008, Val Loss: 31.4095,           Val RMSE: 26.1604, Val MAE: 17.6032
# Epoch 57, Train Loss: 28.9766, Val Loss: 30.8370,           Val RMSE: 22.0118, Val MAE: 15.8070
# Epoch 58, Train Loss: 28.3755, Val Loss: 30.5478,           Val RMSE: 21.2285, Val MAE: 15.2817
# Epoch 59, Train Loss: 27.9989, Val Loss: 30.1157,           Val RMSE: 24.4772, Val MAE: 20.0220
# Epoch 60, Train Loss: 27.5694, Val Loss: 30.3583,           Val RMSE: 35.6957, Val MAE: 23.7418
# Epoch 61, Train Loss: 27.0504, Val Loss: 29.6235,           Val RMSE: 25.3960, Val MAE: 20.3979
# Epoch 62, Train Loss: 26.6636, Val Loss: 29.1507,           Val RMSE: 22.2028, Val MAE: 16.5515
# Epoch 63, Train Loss: 26.5388, Val Loss: 28.8596,           Val RMSE: 23.8093, Val MAE: 19.0095
# Epoch 64, Train Loss: 26.2282, Val Loss: 29.4747,           Val RMSE: 42.2940, Val MAE: 30.2903
# Epoch 65, Train Loss: 26.3892, Val Loss: 28.5539,           Val RMSE: 28.3223, Val MAE: 24.4515
# Epoch 66, Train Loss: 25.7529, Val Loss: 28.6531,           Val RMSE: 32.3592, Val MAE: 21.5909
# Epoch 67, Train Loss: 26.0261, Val Loss: 28.1104,           Val RMSE: 21.5842, Val MAE: 15.6102
# Epoch 68, Train Loss: 25.4994, Val Loss: 28.1340,           Val RMSE: 29.3798, Val MAE: 19.5005
# Epoch 69, Train Loss: 25.0898, Val Loss: 28.1619,           Val RMSE: 29.4823, Val MAE: 19.1668
# Epoch 70, Train Loss: 25.1522, Val Loss: 27.9829,           Val RMSE: 32.3447, Val MAE: 21.7241
# Epoch 71, Train Loss: 24.6453, Val Loss: 27.5038,           Val RMSE: 24.2682, Val MAE: 16.1571
# Epoch 72, Train Loss: 25.0284, Val Loss: 28.2348,           Val RMSE: 49.8030, Val MAE: 44.4258
# Epoch 73, Train Loss: 25.1129, Val Loss: 27.8190,           Val RMSE: 37.9983, Val MAE: 26.7722
# Epoch 74, Train Loss: 24.5244, Val Loss: 27.3081,           Val RMSE: 26.5300, Val MAE: 20.8917
# Epoch 75, Train Loss: 24.1532, Val Loss: 27.0788,           Val RMSE: 23.1747, Val MAE: 15.7412
# Epoch 76, Train Loss: 23.9499, Val Loss: 26.8535,           Val RMSE: 19.3592, Val MAE: 13.6934
# Epoch 77, Train Loss: 23.7596, Val Loss: 27.3265,           Val RMSE: 34.6829, Val MAE: 23.0547
# Epoch 78, Train Loss: 24.1339, Val Loss: 26.8321,           Val RMSE: 24.8251, Val MAE: 16.5759
# Epoch 79, Train Loss: 24.2970, Val Loss: 26.7166,           Val RMSE: 30.8624, Val MAE: 26.5187
# Epoch 80, Train Loss: 23.7606, Val Loss: 26.7216,           Val RMSE: 24.9511, Val MAE: 16.3173
# Epoch 81, Train Loss: 23.5703, Val Loss: 26.4937,           Val RMSE: 19.6758, Val MAE: 13.8385
# Epoch 82, Train Loss: 23.4263, Val Loss: 26.8784,           Val RMSE: 27.8729, Val MAE: 17.7077
# Epoch 83, Train Loss: 23.2705, Val Loss: 26.3335,           Val RMSE: 20.8572, Val MAE: 15.0829
# Epoch 84, Train Loss: 23.1208, Val Loss: 26.1572,           Val RMSE: 20.3333, Val MAE: 14.2305
# Epoch 85, Train Loss: 23.1480, Val Loss: 26.2098,           Val RMSE: 22.0657, Val MAE: 14.4704
# Epoch 86, Train Loss: 22.9998, Val Loss: 26.2305,           Val RMSE: 26.1760, Val MAE: 21.1760
# Epoch 87, Train Loss: 23.1612, Val Loss: 26.3842,           Val RMSE: 33.9754, Val MAE: 28.4111
# Epoch 88, Train Loss: 23.5539, Val Loss: 26.4283,           Val RMSE: 33.1128, Val MAE: 22.0673
# Epoch 89, Train Loss: 24.0993, Val Loss: 29.7833,           Val RMSE: 71.3666, Val MAE: 52.9446
# Epoch 90, Train Loss: 27.8698, Val Loss: 26.3828,           Val RMSE: 24.4152, Val MAE: 19.6534
# Epoch 91, Train Loss: 23.8693, Val Loss: 26.4879,           Val RMSE: 37.6655, Val MAE: 32.2849
# Epoch 92, Train Loss: 23.2349, Val Loss: 25.9940,           Val RMSE: 21.1336, Val MAE: 14.6927
# Epoch 93, Train Loss: 22.4729, Val Loss: 25.6869,           Val RMSE: 19.8118, Val MAE: 13.3214
# Epoch 94, Train Loss: 22.3389, Val Loss: 25.9145,           Val RMSE: 28.9750, Val MAE: 18.8125
# Epoch 95, Train Loss: 22.2323, Val Loss: 25.6390,           Val RMSE: 20.9888, Val MAE: 15.8307
# Epoch 96, Train Loss: 21.9713, Val Loss: 25.4609,           Val RMSE: 19.1369, Val MAE: 12.8550
# Epoch 97, Train Loss: 21.9155, Val Loss: 25.3997,           Val RMSE: 17.9303, Val MAE: 12.5844
# Epoch 98, Train Loss: 21.7690, Val Loss: 25.3996,           Val RMSE: 20.8724, Val MAE: 13.9482
# Epoch 99, Train Loss: 21.7322, Val Loss: 25.5646,           Val RMSE: 22.3406, Val MAE: 14.5991
# Epoch 100, Train Loss: 21.6104, Val Loss: 25.3195,           Val RMSE: 22.8218, Val MAE: 17.2551
# Epoch 101, Train Loss: 21.5324, Val Loss: 25.2105,           Val RMSE: 18.6786, Val MAE: 12.7665
# Epoch 102, Train Loss: 21.5813, Val Loss: 25.1955,           Val RMSE: 18.5582, Val MAE: 13.0896
# Epoch 103, Train Loss: 22.7028, Val Loss: 30.4556,           Val RMSE: 83.8140, Val MAE: 64.8604
# Epoch 104, Train Loss: 28.6270, Val Loss: 31.8720,           Val RMSE: 61.4896, Val MAE: 40.1963
# Epoch 105, Train Loss: 24.2452, Val Loss: 25.9229,           Val RMSE: 38.4210, Val MAE: 31.0877
# Epoch 106, Train Loss: 22.1175, Val Loss: 25.3608,           Val RMSE: 27.8895, Val MAE: 23.4516
# Epoch 107, Train Loss: 21.4022, Val Loss: 25.1220,           Val RMSE: 20.0942, Val MAE: 13.2050
# Epoch 108, Train Loss: 21.2438, Val Loss: 24.9870,           Val RMSE: 19.3297, Val MAE: 13.4483
# Epoch 109, Train Loss: 21.1339, Val Loss: 24.9077,           Val RMSE: 17.5025, Val MAE: 12.0013
# Epoch 110, Train Loss: 20.9771, Val Loss: 24.9578,           Val RMSE: 21.1328, Val MAE: 13.6771
# Epoch 111, Train Loss: 20.8982, Val Loss: 25.1540,           Val RMSE: 27.2850, Val MAE: 17.3836
# Epoch 112, Train Loss: 20.8605, Val Loss: 24.8060,           Val RMSE: 16.9223, Val MAE: 11.8124
# Epoch 113, Train Loss: 20.7268, Val Loss: 24.8165,           Val RMSE: 21.6534, Val MAE: 13.9928
# Epoch 114, Train Loss: 21.1293, Val Loss: 25.4788,           Val RMSE: 25.8814, Val MAE: 18.5500
# Epoch 115, Train Loss: 22.0839, Val Loss: 26.0152,           Val RMSE: 50.7375, Val MAE: 44.8004
# Epoch 116, Train Loss: 21.2228, Val Loss: 24.7691,           Val RMSE: 19.3041, Val MAE: 13.2564
# Epoch 117, Train Loss: 20.5845, Val Loss: 24.7475,           Val RMSE: 21.0631, Val MAE: 13.6353
# Epoch 118, Train Loss: 20.4514, Val Loss: 24.6045,           Val RMSE: 18.6854, Val MAE: 12.2514
# Epoch 119, Train Loss: 20.3557, Val Loss: 24.5887,           Val RMSE: 18.8750, Val MAE: 12.2840
# Epoch 120, Train Loss: 20.3380, Val Loss: 24.5340,           Val RMSE: 18.1578, Val MAE: 12.2490
# Epoch 121, Train Loss: 20.4464, Val Loss: 24.5164,           Val RMSE: 18.3079, Val MAE: 13.3932
# Epoch 122, Train Loss: 20.1951, Val Loss: 24.8477,           Val RMSE: 29.4296, Val MAE: 20.3665
# Epoch 123, Train Loss: 20.1201, Val Loss: 24.4574,           Val RMSE: 17.9207, Val MAE: 11.8547
# Epoch 124, Train Loss: 20.0788, Val Loss: 24.3821,           Val RMSE: 17.2045, Val MAE: 11.3500
# Epoch 125, Train Loss: 19.9523, Val Loss: 24.4137,           Val RMSE: 17.7628, Val MAE: 12.1584
# Epoch 126, Train Loss: 19.8619, Val Loss: 24.3756,           Val RMSE: 16.1464, Val MAE: 10.9138
# Epoch 127, Train Loss: 19.9310, Val Loss: 24.7352,           Val RMSE: 26.8496, Val MAE: 16.8209
# Epoch 128, Train Loss: 21.0902, Val Loss: 25.2880,           Val RMSE: 29.8249, Val MAE: 23.0939
# Epoch 129, Train Loss: 20.5508, Val Loss: 24.5011,           Val RMSE: 20.7817, Val MAE: 15.9289
# Epoch 130, Train Loss: 19.8233, Val Loss: 24.4777,           Val RMSE: 22.0634, Val MAE: 14.4933
# Epoch 131, Train Loss: 19.6764, Val Loss: 24.2967,           Val RMSE: 18.3667, Val MAE: 13.3120
# Epoch 132, Train Loss: 19.5896, Val Loss: 24.6480,           Val RMSE: 23.9502, Val MAE: 18.0381
# Epoch 133, Train Loss: 19.9903, Val Loss: 25.3021,           Val RMSE: 42.6511, Val MAE: 29.6617
# Epoch 134, Train Loss: 19.6841, Val Loss: 24.1847,           Val RMSE: 17.8058, Val MAE: 12.2301
# Epoch 135, Train Loss: 19.5758, Val Loss: 24.3280,           Val RMSE: 15.5321, Val MAE: 10.1929
# Epoch 136, Train Loss: 19.3709, Val Loss: 24.2369,           Val RMSE: 18.7995, Val MAE: 11.9674
# Epoch 137, Train Loss: 19.2837, Val Loss: 24.2335,           Val RMSE: 15.5514, Val MAE: 10.5957
# Epoch 138, Train Loss: 19.2112, Val Loss: 24.1823,           Val RMSE: 16.4295, Val MAE: 11.4694
# Epoch 139, Train Loss: 19.2088, Val Loss: 25.1862,           Val RMSE: 37.0168, Val MAE: 23.8649
# Epoch 140, Train Loss: 19.7170, Val Loss: 24.2808,           Val RMSE: 20.2796, Val MAE: 14.7681
# Epoch 141, Train Loss: 19.2952, Val Loss: 24.0822,           Val RMSE: 17.1528, Val MAE: 11.5611
# Epoch 142, Train Loss: 19.3334, Val Loss: 24.0835,           Val RMSE: 17.6181, Val MAE: 12.5894
# Epoch 143, Train Loss: 19.1548, Val Loss: 24.1984,           Val RMSE: 18.2116, Val MAE: 13.5319
# Epoch 144, Train Loss: 18.8734, Val Loss: 24.1040,           Val RMSE: 16.7138, Val MAE: 11.1107
# Epoch 145, Train Loss: 18.8622, Val Loss: 24.1340,           Val RMSE: 17.3668, Val MAE: 12.4418
# Epoch 146, Train Loss: 18.7383, Val Loss: 24.0659,           Val RMSE: 15.7275, Val MAE: 10.4333
# Epoch 147, Train Loss: 18.7921, Val Loss: 24.0590,           Val RMSE: 16.4666, Val MAE: 11.8098
# Epoch 148, Train Loss: 18.6886, Val Loss: 24.0091,           Val RMSE: 17.1472, Val MAE: 11.1593
# Epoch 149, Train Loss: 18.9006, Val Loss: 24.5666,           Val RMSE: 28.0634, Val MAE: 22.3715
# Epoch 150, Train Loss: 19.5043, Val Loss: 24.4449,           Val RMSE: 21.7590, Val MAE: 17.1670
# Epoch 151, Train Loss: 18.8984, Val Loss: 24.1051,           Val RMSE: 19.6681, Val MAE: 13.8365
# Epoch 152, Train Loss: 18.6474, Val Loss: 24.0679,           Val RMSE: 18.0396, Val MAE: 11.8447
# Epoch 153, Train Loss: 18.3888, Val Loss: 23.9884,           Val RMSE: 15.7864, Val MAE: 10.4337
# Epoch 154, Train Loss: 18.3501, Val Loss: 24.0386,           Val RMSE: 17.5547, Val MAE: 12.8507
# Epoch 155, Train Loss: 18.2717, Val Loss: 24.0844,           Val RMSE: 17.2883, Val MAE: 11.1890
# Epoch 156, Train Loss: 18.2934, Val Loss: 24.0302,           Val RMSE: 17.5881, Val MAE: 12.2319
# Epoch 157, Train Loss: 18.1777, Val Loss: 24.0618,           Val RMSE: 17.6852, Val MAE: 12.9612
# Epoch 158, Train Loss: 18.1630, Val Loss: 24.0761,           Val RMSE: 20.6194, Val MAE: 12.8594
# Epoch 159, Train Loss: 18.2293, Val Loss: 24.0004,           Val RMSE: 17.7774, Val MAE: 12.4526
# Epoch 160, Train Loss: 18.1060, Val Loss: 24.1256,           Val RMSE: 20.9618, Val MAE: 16.3658
# Epoch 161, Train Loss: 18.2444, Val Loss: 24.4983,           Val RMSE: 34.4279, Val MAE: 25.9352
# Epoch 162, Train Loss: 18.6567, Val Loss: 25.1177,           Val RMSE: 45.2921, Val MAE: 33.1954
# Epoch 163, Train Loss: 18.8700, Val Loss: 23.8596,           Val RMSE: 17.6416, Val MAE: 11.8589
# Epoch 164, Train Loss: 18.4337, Val Loss: 24.5137,           Val RMSE: 32.9071, Val MAE: 21.2846
# Epoch 165, Train Loss: 20.3683, Val Loss: 25.4218,           Val RMSE: 31.2910, Val MAE: 24.6394
# Epoch 166, Train Loss: 19.2670, Val Loss: 24.7693,           Val RMSE: 18.7789, Val MAE: 12.7062
# Epoch 167, Train Loss: 18.2717, Val Loss: 23.7757,           Val RMSE: 16.7651, Val MAE: 11.3317
# Epoch 168, Train Loss: 18.0861, Val Loss: 23.9078,           Val RMSE: 16.3032, Val MAE: 10.5349
# Epoch 169, Train Loss: 17.7611, Val Loss: 23.9098,           Val RMSE: 16.9953, Val MAE: 11.3013
# Epoch 170, Train Loss: 17.5889, Val Loss: 23.8070,           Val RMSE: 16.2747, Val MAE: 10.7265
# Epoch 171, Train Loss: 17.4826, Val Loss: 23.8136,           Val RMSE: 15.8507, Val MAE: 10.5503
# Epoch 172, Train Loss: 17.4083, Val Loss: 23.8330,           Val RMSE: 15.3379, Val MAE: 10.3846
# Epoch 173, Train Loss: 17.3710, Val Loss: 23.9211,           Val RMSE: 16.2272, Val MAE: 10.7827
# Epoch 174, Train Loss: 17.4814, Val Loss: 24.1648,           Val RMSE: 27.1733, Val MAE: 19.3503
# Epoch 175, Train Loss: 17.4229, Val Loss: 23.9701,           Val RMSE: 20.4347, Val MAE: 12.4184
# Epoch 176, Train Loss: 17.3726, Val Loss: 23.9508,           Val RMSE: 16.5164, Val MAE: 10.8327
# Epoch 177, Train Loss: 17.1423, Val Loss: 23.9232,           Val RMSE: 15.5727, Val MAE: 10.4376
# Epoch 178, Train Loss: 17.3259, Val Loss: 24.9506,           Val RMSE: 34.8584, Val MAE: 29.4223
# Epoch 179, Train Loss: 18.4581, Val Loss: 26.3479,           Val RMSE: 59.2810, Val MAE: 43.9136
# Epoch 180, Train Loss: 17.5852, Val Loss: 23.9741,           Val RMSE: 19.1102, Val MAE: 12.5314
# Epoch 181, Train Loss: 17.0264, Val Loss: 23.9366,           Val RMSE: 22.3120, Val MAE: 14.5031
# Epoch 182, Train Loss: 17.1418, Val Loss: 24.0047,           Val RMSE: 24.6782, Val MAE: 16.4689
# Epoch 183, Train Loss: 16.9674, Val Loss: 23.9694,           Val RMSE: 16.6137, Val MAE: 10.5144
# Epoch 184, Train Loss: 16.8905, Val Loss: 23.9444,           Val RMSE: 16.0376, Val MAE: 10.2274
# Epoch 185, Train Loss: 16.9871, Val Loss: 24.1708,           Val RMSE: 23.7191, Val MAE: 14.8314
# Epoch 186, Train Loss: 16.8781, Val Loss: 23.8759,           Val RMSE: 18.9033, Val MAE: 12.1875
# Epoch 187, Train Loss: 16.7720, Val Loss: 24.0297,           Val RMSE: 17.8257, Val MAE: 13.3869
# Epoch 188, Train Loss: 16.5796, Val Loss: 23.9134,           Val RMSE: 17.3642, Val MAE: 11.0312
# Epoch 189, Train Loss: 16.4696, Val Loss: 24.0169,           Val RMSE: 17.4410, Val MAE: 11.1553
# Epoch 190, Train Loss: 16.4095, Val Loss: 23.9496,           Val RMSE: 17.0519, Val MAE: 10.9284
# Epoch 191, Train Loss: 16.3441, Val Loss: 24.0091,           Val RMSE: 18.8603, Val MAE: 12.3402
# Epoch 192, Train Loss: 16.3217, Val Loss: 24.2492,           Val RMSE: 17.4272, Val MAE: 12.2009
# Epoch 193, Train Loss: 16.3521, Val Loss: 24.1329,           Val RMSE: 20.8696, Val MAE: 12.7444
# Epoch 194, Train Loss: 16.4369, Val Loss: 24.2455,           Val RMSE: 26.1278, Val MAE: 16.6129
# Epoch 195, Train Loss: 16.4488, Val Loss: 24.1091,           Val RMSE: 18.6845, Val MAE: 12.0965
# Epoch 196, Train Loss: 16.1017, Val Loss: 24.1820,           Val RMSE: 16.3927, Val MAE: 10.9448
# Epoch 197, Train Loss: 16.2887, Val Loss: 24.1184,           Val RMSE: 18.9983, Val MAE: 12.8723
# Epoch 198, Train Loss: 16.8198, Val Loss: 23.9327,           Val RMSE: 19.2954, Val MAE: 12.5625
# Epoch 199, Train Loss: 16.5344, Val Loss: 24.3938,           Val RMSE: 28.4958, Val MAE: 17.8834
# Epoch 200, Train Loss: 16.5691, Val Loss: 24.3970,           Val RMSE: 34.6903, Val MAE: 27.1026
# Epoch 201, Train Loss: 15.9968, Val Loss: 24.1530,           Val RMSE: 18.2830, Val MAE: 11.2633
# Epoch 202, Train Loss: 15.9317, Val Loss: 24.1872,           Val RMSE: 24.3982, Val MAE: 15.6608
# Epoch 203, Train Loss: 15.8354, Val Loss: 24.3086,           Val RMSE: 27.5529, Val MAE: 18.0722
# Epoch 204, Train Loss: 16.0273, Val Loss: 25.7478,           Val RMSE: 51.6579, Val MAE: 39.4364
# Epoch 205, Train Loss: 15.8677, Val Loss: 24.0511,           Val RMSE: 19.3177, Val MAE: 11.8685
# Epoch 206, Train Loss: 15.5287, Val Loss: 24.2111,           Val RMSE: 15.7352, Val MAE: 10.0583
# Epoch 207, Train Loss: 15.4669, Val Loss: 24.1863,           Val RMSE: 21.3871, Val MAE: 13.7966
# Epoch 208, Train Loss: 15.4421, Val Loss: 24.2419,           Val RMSE: 16.9527, Val MAE: 11.5980
# Epoch 209, Train Loss: 15.3515, Val Loss: 24.3598,           Val RMSE: 24.2134, Val MAE: 15.3997
# Epoch 210, Train Loss: 15.5134, Val Loss: 25.0980,           Val RMSE: 20.9454, Val MAE: 14.2681
# Epoch 211, Train Loss: 15.4270, Val Loss: 24.2820,           Val RMSE: 16.4152, Val MAE: 10.9361
# Epoch 212, Train Loss: 15.3018, Val Loss: 24.3043,           Val RMSE: 23.9353, Val MAE: 16.7947
# Epoch 213, Train Loss: 15.0890, Val Loss: 24.2620,           Val RMSE: 17.1373, Val MAE: 10.9337
# Epoch 214, Train Loss: 15.0234, Val Loss: 24.4055,           Val RMSE: 17.0445, Val MAE: 11.0147
# Epoch 215, Train Loss: 15.0381, Val Loss: 24.3800,           Val RMSE: 22.1585, Val MAE: 14.3455
# Epoch 216, Train Loss: 15.1798, Val Loss: 25.5455,           Val RMSE: 41.5083, Val MAE: 36.1793
# Epoch 217, Train Loss: 15.8765, Val Loss: 25.4139,           Val RMSE: 32.1737, Val MAE: 25.8170
# Epoch 218, Train Loss: 15.2980, Val Loss: 24.4653,           Val RMSE: 17.0133, Val MAE: 11.9226
# Epoch 219, Train Loss: 14.7641, Val Loss: 24.5409,           Val RMSE: 15.3634, Val MAE: 9.9352
# Epoch 220, Train Loss: 14.6683, Val Loss: 24.3951,           Val RMSE: 18.6408, Val MAE: 11.4945
# Epoch 221, Train Loss: 14.6986, Val Loss: 25.0287,           Val RMSE: 20.1789, Val MAE: 14.0345
# Epoch 222, Train Loss: 14.7161, Val Loss: 25.3902,           Val RMSE: 43.4893, Val MAE: 31.5250
# Epoch 223, Train Loss: 15.0528, Val Loss: 26.6942,           Val RMSE: 60.7729, Val MAE: 47.2820
# Epoch 224, Train Loss: 15.3948, Val Loss: 24.3719,           Val RMSE: 24.5460, Val MAE: 15.2257
# Epoch 225, Train Loss: 14.3604, Val Loss: 24.6020,           Val RMSE: 15.5868, Val MAE: 9.9976
# Epoch 226, Train Loss: 14.1026, Val Loss: 24.5800,           Val RMSE: 21.2837, Val MAE: 13.2434
# Epoch 227, Train Loss: 14.0546, Val Loss: 24.5731,           Val RMSE: 17.4094, Val MAE: 11.3651
# Epoch 228, Train Loss: 13.9122, Val Loss: 24.8591,           Val RMSE: 14.9774, Val MAE: 9.5918
# Epoch 229, Train Loss: 13.8126, Val Loss: 24.8221,           Val RMSE: 23.7772, Val MAE: 15.6423
# Epoch 230, Train Loss: 13.8034, Val Loss: 24.8413,           Val RMSE: 16.3641, Val MAE: 10.8946
# Epoch 231, Train Loss: 13.6866, Val Loss: 25.0792,           Val RMSE: 16.5820, Val MAE: 11.6657
# Epoch 232, Train Loss: 13.6199, Val Loss: 25.1039,           Val RMSE: 30.5336, Val MAE: 20.4285
# Epoch 233, Train Loss: 13.7935, Val Loss: 24.9742,           Val RMSE: 17.3169, Val MAE: 10.5481
# Epoch 234, Train Loss: 13.4196, Val Loss: 24.9473,           Val RMSE: 16.1095, Val MAE: 10.0778
# Epoch 235, Train Loss: 13.3030, Val Loss: 25.1198,           Val RMSE: 16.2231, Val MAE: 10.3589
# Epoch 236, Train Loss: 13.1989, Val Loss: 25.1121,           Val RMSE: 23.5096, Val MAE: 15.4955
# Epoch 237, Train Loss: 13.1445, Val Loss: 25.1062,           Val RMSE: 24.5785, Val MAE: 17.0379
# Epoch 238, Train Loss: 13.7880, Val Loss: 26.1309,           Val RMSE: 17.5727, Val MAE: 10.7176
# Epoch 239, Train Loss: 15.1135, Val Loss: 25.4973,           Val RMSE: 42.0262, Val MAE: 29.7277
# Epoch 240, Train Loss: 14.6777, Val Loss: 25.6875,           Val RMSE: 21.7120, Val MAE: 14.7144
# Epoch 241, Train Loss: 14.2613, Val Loss: 24.7747,           Val RMSE: 21.1217, Val MAE: 12.7990
# Epoch 242, Train Loss: 13.1842, Val Loss: 25.1763,           Val RMSE: 16.6181, Val MAE: 10.8718
# Epoch 243, Train Loss: 12.7834, Val Loss: 25.2443,           Val RMSE: 17.8257, Val MAE: 11.4530
# Epoch 244, Train Loss: 12.9441, Val Loss: 25.2492,           Val RMSE: 18.9644, Val MAE: 11.4152
# Epoch 245, Train Loss: 12.4881, Val Loss: 25.3375,           Val RMSE: 18.8955, Val MAE: 12.4449
# Epoch 246, Train Loss: 12.3740, Val Loss: 25.4664,           Val RMSE: 18.9068, Val MAE: 11.7608
# Epoch 247, Train Loss: 12.3447, Val Loss: 25.9873,           Val RMSE: 18.5138, Val MAE: 13.2412
# Epoch 248, Train Loss: 12.5816, Val Loss: 26.0649,           Val RMSE: 18.5648, Val MAE: 14.1714
# Epoch 249, Train Loss: 12.6413, Val Loss: 25.8181,           Val RMSE: 17.9397, Val MAE: 12.9737
# Epoch 250, Train Loss: 12.3318, Val Loss: 25.5669,           Val RMSE: 21.9377, Val MAE: 14.4148
# Epoch 251, Train Loss: 13.6132, Val Loss: 25.5319,           Val RMSE: 20.5241, Val MAE: 16.0934
# Epoch 252, Train Loss: 12.8564, Val Loss: 25.7396,           Val RMSE: 32.5732, Val MAE: 24.2626
# Epoch 253, Train Loss: 12.0489, Val Loss: 26.0637,           Val RMSE: 15.7898, Val MAE: 10.7878
# Epoch 254, Train Loss: 11.7552, Val Loss: 25.7261,           Val RMSE: 23.5192, Val MAE: 16.2063
# Epoch 255, Train Loss: 11.6032, Val Loss: 26.0370,           Val RMSE: 31.4863, Val MAE: 21.3396
# Epoch 256, Train Loss: 11.7265, Val Loss: 26.4713,           Val RMSE: 16.0091, Val MAE: 10.5421
# Epoch 257, Train Loss: 11.4829, Val Loss: 27.2641,           Val RMSE: 21.1407, Val MAE: 14.8282
# Epoch 258, Train Loss: 11.5010, Val Loss: 26.8687,           Val RMSE: 18.5778, Val MAE: 13.9418
# Epoch 259, Train Loss: 11.2009, Val Loss: 27.0072,           Val RMSE: 19.5163, Val MAE: 14.4691
# Epoch 260, Train Loss: 11.3405, Val Loss: 26.4689,           Val RMSE: 17.5938, Val MAE: 12.9537
# Epoch 261, Train Loss: 10.8886, Val Loss: 26.2543,           Val RMSE: 22.8103, Val MAE: 14.3947
# Epoch 262, Train Loss: 10.7765, Val Loss: 26.4253,           Val RMSE: 23.4101, Val MAE: 14.4944
# Epoch 263, Train Loss: 10.8015, Val Loss: 27.0133,           Val RMSE: 17.8123, Val MAE: 13.1766
# Epoch 264, Train Loss: 10.4559, Val Loss: 26.6726,           Val RMSE: 19.6871, Val MAE: 12.5992
# Epoch 265, Train Loss: 10.3485, Val Loss: 26.7978,           Val RMSE: 19.2430, Val MAE: 12.3219
# Epoch 266, Train Loss: 10.2969, Val Loss: 26.8197,           Val RMSE: 20.9233, Val MAE: 13.1750
# Epoch 267, Train Loss: 10.1722, Val Loss: 27.0355,           Val RMSE: 16.5181, Val MAE: 10.5567
# Epoch 268, Train Loss: 10.5279, Val Loss: 28.5402,           Val RMSE: 22.9232, Val MAE: 18.1834
# Epoch 269, Train Loss: 11.6018, Val Loss: 27.1420,           Val RMSE: 40.8053, Val MAE: 32.5206
# Epoch 270, Train Loss: 10.5066, Val Loss: 26.9528,           Val RMSE: 20.6631, Val MAE: 14.7149
# Epoch 271, Train Loss: 10.5042, Val Loss: 26.9053,           Val RMSE: 18.9426, Val MAE: 12.1384
# Epoch 272, Train Loss: 9.7746, Val Loss: 27.2897,           Val RMSE: 16.9774, Val MAE: 11.6706
# Epoch 273, Train Loss: 9.6229, Val Loss: 27.3668,           Val RMSE: 16.9623, Val MAE: 10.7364
# Epoch 274, Train Loss: 9.3408, Val Loss: 27.2938,           Val RMSE: 21.3262, Val MAE: 13.8977
# Epoch 275, Train Loss: 9.2114, Val Loss: 28.2412,           Val RMSE: 15.8023, Val MAE: 10.1475
# Epoch 276, Train Loss: 9.1542, Val Loss: 27.6306,           Val RMSE: 21.4850, Val MAE: 14.5700
# Epoch 277, Train Loss: 8.9182, Val Loss: 27.6870,           Val RMSE: 18.9286, Val MAE: 12.0252
# Epoch 278, Train Loss: 8.9598, Val Loss: 28.5112,           Val RMSE: 16.4980, Val MAE: 11.1911
# Epoch 279, Train Loss: 9.5128, Val Loss: 28.8278,           Val RMSE: 19.1355, Val MAE: 13.8089
# Epoch 280, Train Loss: 9.1285, Val Loss: 27.7002,           Val RMSE: 19.7695, Val MAE: 12.9920
# Epoch 281, Train Loss: 8.7766, Val Loss: 28.4360,           Val RMSE: 15.7014, Val MAE: 10.3968
# Epoch 282, Train Loss: 8.6145, Val Loss: 27.8425,           Val RMSE: 20.6021, Val MAE: 12.9802
# Epoch 283, Train Loss: 8.3494, Val Loss: 28.5120,           Val RMSE: 17.0778, Val MAE: 11.5930
# Epoch 284, Train Loss: 8.2098, Val Loss: 28.4436,           Val RMSE: 16.8649, Val MAE: 10.4366
# Epoch 285, Train Loss: 8.0372, Val Loss: 28.3307,           Val RMSE: 22.1438, Val MAE: 14.8996
# Epoch 286, Train Loss: 8.0160, Val Loss: 28.8271,           Val RMSE: 16.5559, Val MAE: 10.2079
# Epoch 287, Train Loss: 7.8676, Val Loss: 28.6424,           Val RMSE: 17.9015, Val MAE: 11.4947
# Epoch 288, Train Loss: 7.7781, Val Loss: 28.5314,           Val RMSE: 22.5050, Val MAE: 14.2766
# Epoch 289, Train Loss: 7.5477, Val Loss: 28.9819,           Val RMSE: 19.0715, Val MAE: 11.8557
# Epoch 290, Train Loss: 7.4026, Val Loss: 28.8054,           Val RMSE: 24.0215, Val MAE: 15.7348
# Epoch 291, Train Loss: 7.2693, Val Loss: 29.1401,           Val RMSE: 17.4156, Val MAE: 10.7873
# Epoch 292, Train Loss: 7.1415, Val Loss: 29.1250,           Val RMSE: 21.0439, Val MAE: 13.4771
# Epoch 293, Train Loss: 7.1136, Val Loss: 29.2767,           Val RMSE: 22.3363, Val MAE: 14.4426
# Epoch 294, Train Loss: 6.9490, Val Loss: 29.2782,           Val RMSE: 17.8950, Val MAE: 11.6847
# Epoch 295, Train Loss: 6.8195, Val Loss: 29.9238,           Val RMSE: 16.5598, Val MAE: 11.5927
# Epoch 296, Train Loss: 6.7026, Val Loss: 30.2494,           Val RMSE: 16.4303, Val MAE: 10.0295
# Epoch 297, Train Loss: 6.7230, Val Loss: 29.6586,           Val RMSE: 19.1963, Val MAE: 11.9632
# Epoch 298, Train Loss: 6.6320, Val Loss: 29.8226,           Val RMSE: 16.2715, Val MAE: 9.9733
# Epoch 299, Train Loss: 6.4042, Val Loss: 29.9292,           Val RMSE: 18.8973, Val MAE: 11.6204
# Epoch 300, Train Loss: 6.4024, Val Loss: 30.8200,           Val RMSE: 17.4062, Val MAE: 11.8534
# Epoch 301, Train Loss: 6.3382, Val Loss: 30.0946,           Val RMSE: 22.6799, Val MAE: 15.4891
# Epoch 302, Train Loss: 6.2128, Val Loss: 29.9519,           Val RMSE: 29.8830, Val MAE: 21.7603
# Epoch 303, Train Loss: 6.3828, Val Loss: 31.3246,           Val RMSE: 17.1776, Val MAE: 10.5308
# Epoch 304, Train Loss: 6.6298, Val Loss: 30.3763,           Val RMSE: 18.6157, Val MAE: 11.6449
# Epoch 305, Train Loss: 7.9835, Val Loss: 30.9680,           Val RMSE: 52.9288, Val MAE: 43.1747
# Epoch 306, Train Loss: 7.9455, Val Loss: 29.1634,           Val RMSE: 22.5785, Val MAE: 16.5223
# Epoch 307, Train Loss: 6.3844, Val Loss: 30.0286,           Val RMSE: 16.8788, Val MAE: 10.4031
# Epoch 308, Train Loss: 5.9447, Val Loss: 29.9468,           Val RMSE: 24.8154, Val MAE: 16.7215
# Epoch 309, Train Loss: 5.6942, Val Loss: 30.3559,           Val RMSE: 23.6446, Val MAE: 15.0056
# Epoch 310, Train Loss: 5.5268, Val Loss: 30.6026,           Val RMSE: 19.7908, Val MAE: 12.9204
# Epoch 311, Train Loss: 5.6120, Val Loss: 30.3994,           Val RMSE: 29.5575, Val MAE: 19.7081
# Epoch 312, Train Loss: 5.5278, Val Loss: 30.5467,           Val RMSE: 26.2210, Val MAE: 17.2321
# Epoch 313, Train Loss: 6.2232, Val Loss: 30.6004,           Val RMSE: 21.1208, Val MAE: 13.8366
# Epoch 314, Train Loss: 5.9008, Val Loss: 30.6905,           Val RMSE: 49.1788, Val MAE: 37.6215
# Epoch 315, Train Loss: 8.5451, Val Loss: 32.1609,           Val RMSE: 30.0655, Val MAE: 27.0061
# Epoch 316, Train Loss: 6.5481, Val Loss: 30.8547,           Val RMSE: 20.1825, Val MAE: 12.5401
# Epoch 317, Train Loss: 5.9532, Val Loss: 31.6150,           Val RMSE: 19.3381, Val MAE: 14.5246
# Epoch 318, Train Loss: 5.6795, Val Loss: 30.8657,           Val RMSE: 21.7633, Val MAE: 13.7987
# Epoch 319, Train Loss: 5.4295, Val Loss: 30.3710,           Val RMSE: 35.2686, Val MAE: 26.3533
# Epoch 320, Train Loss: 5.0396, Val Loss: 31.4277,           Val RMSE: 16.1560, Val MAE: 10.7746
# Epoch 321, Train Loss: 4.7480, Val Loss: 31.1679,           Val RMSE: 17.7168, Val MAE: 10.7378
# Epoch 322, Train Loss: 4.6331, Val Loss: 31.4985,           Val RMSE: 16.7909, Val MAE: 10.1930
# Epoch 323, Train Loss: 4.6059, Val Loss: 31.3432,           Val RMSE: 20.1817, Val MAE: 12.8708
# Epoch 324, Train Loss: 4.5713, Val Loss: 31.0464,           Val RMSE: 28.6081, Val MAE: 20.6589
# Epoch 325, Train Loss: 4.5004, Val Loss: 31.2779,           Val RMSE: 24.8504, Val MAE: 16.3197
# Epoch 326, Train Loss: 4.4410, Val Loss: 32.5730,           Val RMSE: 16.8346, Val MAE: 11.4001
# Epoch 327, Train Loss: 4.4378, Val Loss: 31.8442,           Val RMSE: 19.1582, Val MAE: 12.1304
# Epoch 328, Train Loss: 4.3142, Val Loss: 32.2194,           Val RMSE: 16.3895, Val MAE: 10.3618
# Epoch 329, Train Loss: 4.2194, Val Loss: 31.6421,           Val RMSE: 22.3822, Val MAE: 15.7116
# Epoch 330, Train Loss: 4.2437, Val Loss: 31.7508,           Val RMSE: 21.9763, Val MAE: 14.3390
# Epoch 331, Train Loss: 4.6840, Val Loss: 31.6930,           Val RMSE: 21.0962, Val MAE: 13.2556
# Epoch 332, Train Loss: 4.3690, Val Loss: 32.3689,           Val RMSE: 22.3571, Val MAE: 13.7407
# Epoch 333, Train Loss: 4.5871, Val Loss: 31.3881,           Val RMSE: 37.7991, Val MAE: 26.4142
# Epoch 334, Train Loss: 5.0051, Val Loss: 33.7137,           Val RMSE: 19.3057, Val MAE: 13.3079
# Epoch 335, Train Loss: 6.1103, Val Loss: 30.7800,           Val RMSE: 43.5612, Val MAE: 28.2987
# Epoch 336, Train Loss: 5.8519, Val Loss: 32.9215,           Val RMSE: 27.9307, Val MAE: 24.3330
# Epoch 337, Train Loss: 4.5195, Val Loss: 31.9306,           Val RMSE: 19.3103, Val MAE: 12.5600
# Epoch 338, Train Loss: 4.1103, Val Loss: 32.0495,           Val RMSE: 19.9893, Val MAE: 12.0616
# Epoch 339, Train Loss: 3.9480, Val Loss: 31.8146,           Val RMSE: 20.2365, Val MAE: 12.4724
# Epoch 340, Train Loss: 3.9402, Val Loss: 31.5078,           Val RMSE: 28.0919, Val MAE: 18.1351
# Epoch 341, Train Loss: 3.7716, Val Loss: 32.3368,           Val RMSE: 16.4445, Val MAE: 10.0078
# Epoch 342, Train Loss: 3.7954, Val Loss: 33.5015,           Val RMSE: 17.6951, Val MAE: 12.5310
# Epoch 343, Train Loss: 3.6260, Val Loss: 32.2249,           Val RMSE: 21.4640, Val MAE: 14.6540
# Epoch 344, Train Loss: 3.6139, Val Loss: 32.2054,           Val RMSE: 21.0256, Val MAE: 13.4585
# Epoch 345, Train Loss: 3.5989, Val Loss: 32.9499,           Val RMSE: 17.8528, Val MAE: 11.5814
# Epoch 346, Train Loss: 3.4713, Val Loss: 32.7940,           Val RMSE: 16.4976, Val MAE: 10.5997
# Epoch 347, Train Loss: 3.4061, Val Loss: 32.6840,           Val RMSE: 17.9294, Val MAE: 10.8189
# Epoch 348, Train Loss: 3.3678, Val Loss: 32.5294,           Val RMSE: 19.3987, Val MAE: 12.1680
# Epoch 349, Train Loss: 3.3728, Val Loss: 32.6065,           Val RMSE: 19.4835, Val MAE: 12.4139
# Epoch 350, Train Loss: 3.3688, Val Loss: 32.4576,           Val RMSE: 22.9160, Val MAE: 14.6988
# Epoch 351, Train Loss: 3.3243, Val Loss: 32.4583,           Val RMSE: 22.8147, Val MAE: 15.6428
# Epoch 352, Train Loss: 3.2609, Val Loss: 32.7338,           Val RMSE: 21.7029, Val MAE: 14.7245
# Epoch 353, Train Loss: 3.2057, Val Loss: 32.7390,           Val RMSE: 20.3154, Val MAE: 13.4075
# Epoch 354, Train Loss: 3.2222, Val Loss: 33.0151,           Val RMSE: 18.7656, Val MAE: 12.4218
# Epoch 355, Train Loss: 3.2312, Val Loss: 32.9459,           Val RMSE: 18.2364, Val MAE: 11.2968
# Epoch 356, Train Loss: 3.1388, Val Loss: 32.6619,           Val RMSE: 22.7689, Val MAE: 14.9440
# Epoch 357, Train Loss: 3.1416, Val Loss: 33.5954,           Val RMSE: 16.6540, Val MAE: 11.0352
# Epoch 358, Train Loss: 3.0980, Val Loss: 32.8599,           Val RMSE: 23.9511, Val MAE: 15.4671
# Epoch 359, Train Loss: 3.1279, Val Loss: 32.9977,           Val RMSE: 21.0756, Val MAE: 13.1775
# Epoch 360, Train Loss: 3.0700, Val Loss: 33.4468,           Val RMSE: 16.6302, Val MAE: 10.2169
# Epoch 361, Train Loss: 3.0520, Val Loss: 32.9911,           Val RMSE: 21.3449, Val MAE: 14.1737
# Epoch 362, Train Loss: 2.9912, Val Loss: 33.2495,           Val RMSE: 19.8368, Val MAE: 12.3602
# Epoch 363, Train Loss: 2.9651, Val Loss: 33.0979,           Val RMSE: 22.3502, Val MAE: 15.5946
# Epoch 364, Train Loss: 2.9225, Val Loss: 33.3627,           Val RMSE: 19.3110, Val MAE: 11.7389
# Epoch 365, Train Loss: 2.8978, Val Loss: 33.3563,           Val RMSE: 20.4167, Val MAE: 13.3573
# Epoch 366, Train Loss: 2.8797, Val Loss: 33.4484,           Val RMSE: 19.0897, Val MAE: 11.6176
# Epoch 367, Train Loss: 2.8755, Val Loss: 33.3740,           Val RMSE: 19.7807, Val MAE: 12.5616
# Epoch 368, Train Loss: 3.0049, Val Loss: 33.4792,           Val RMSE: 16.7640, Val MAE: 10.0498
# Epoch 369, Train Loss: 4.3464, Val Loss: 32.7752,           Val RMSE: 30.4671, Val MAE: 21.5456
# Epoch 370, Train Loss: 4.7562, Val Loss: 32.0364,           Val RMSE: 27.7991, Val MAE: 18.0610
# Epoch 371, Train Loss: 3.2867, Val Loss: 32.7812,           Val RMSE: 20.8824, Val MAE: 12.6525
# Epoch 372, Train Loss: 2.9930, Val Loss: 33.5539,           Val RMSE: 16.7696, Val MAE: 10.0423
# Epoch 373, Train Loss: 2.9240, Val Loss: 32.7831,           Val RMSE: 28.4414, Val MAE: 19.9779
# Epoch 374, Train Loss: 2.9362, Val Loss: 33.2383,           Val RMSE: 19.8626, Val MAE: 12.2155
# Epoch 375, Train Loss: 2.7933, Val Loss: 33.1329,           Val RMSE: 20.6091, Val MAE: 13.4064
# Epoch 376, Train Loss: 2.7557, Val Loss: 33.3571,           Val RMSE: 19.3776, Val MAE: 11.9880
# Epoch 377, Train Loss: 2.7300, Val Loss: 33.7413,           Val RMSE: 17.8589, Val MAE: 10.7980
# Epoch 378, Train Loss: 2.7098, Val Loss: 33.3070,           Val RMSE: 20.5054, Val MAE: 12.9429
# Epoch 379, Train Loss: 2.6830, Val Loss: 33.5990,           Val RMSE: 18.3026, Val MAE: 11.0509
# Epoch 380, Train Loss: 2.6721, Val Loss: 33.3887,           Val RMSE: 19.7118, Val MAE: 12.0430
# Epoch 381, Train Loss: 2.6661, Val Loss: 33.7722,           Val RMSE: 21.3535, Val MAE: 14.3705
# Epoch 382, Train Loss: 2.7019, Val Loss: 33.9630,           Val RMSE: 16.5205, Val MAE: 9.9956
# Epoch 383, Train Loss: 2.8363, Val Loss: 33.8706,           Val RMSE: 16.5213, Val MAE: 10.1660
# Epoch 384, Train Loss: 2.7050, Val Loss: 33.4014,           Val RMSE: 25.6464, Val MAE: 17.0680
# Epoch 385, Train Loss: 2.8448, Val Loss: 33.6013,           Val RMSE: 23.8405, Val MAE: 14.9149
# Epoch 386, Train Loss: 2.7676, Val Loss: 33.8552,           Val RMSE: 17.3770, Val MAE: 10.5915
# Epoch 387, Train Loss: 2.7079, Val Loss: 33.4345,           Val RMSE: 20.7603, Val MAE: 14.0533
# Epoch 388, Train Loss: 2.8358, Val Loss: 33.8646,           Val RMSE: 19.8148, Val MAE: 13.6623
# Epoch 389, Train Loss: 2.6676, Val Loss: 34.4197,           Val RMSE: 17.2528, Val MAE: 10.5533
# Epoch 390, Train Loss: 2.6798, Val Loss: 33.8984,           Val RMSE: 17.0625, Val MAE: 10.6586
# Epoch 391, Train Loss: 2.5987, Val Loss: 33.5147,           Val RMSE: 21.1230, Val MAE: 14.0540
# Epoch 392, Train Loss: 2.5428, Val Loss: 33.5859,           Val RMSE: 19.2182, Val MAE: 11.7700
# Epoch 393, Train Loss: 2.5200, Val Loss: 33.5249,           Val RMSE: 21.7157, Val MAE: 14.1751
# Epoch 394, Train Loss: 2.4952, Val Loss: 33.8438,           Val RMSE: 20.1589, Val MAE: 12.6287
# Epoch 395, Train Loss: 2.4906, Val Loss: 33.8039,           Val RMSE: 21.1866, Val MAE: 13.7349
# Epoch 396, Train Loss: 2.4742, Val Loss: 33.7406,           Val RMSE: 20.4032, Val MAE: 13.0186
# Epoch 397, Train Loss: 2.4670, Val Loss: 33.9186,           Val RMSE: 20.5043, Val MAE: 13.8133
# Epoch 398, Train Loss: 2.4469, Val Loss: 33.7656,           Val RMSE: 20.7415, Val MAE: 13.3080
# Epoch 399, Train Loss: 2.4455, Val Loss: 34.1104,           Val RMSE: 18.4188, Val MAE: 11.4624
# Epoch 400, Train Loss: 2.4393, Val Loss: 33.9106,           Val RMSE: 21.6607, Val MAE: 14.7486
# CPU times: user 51min 46s, sys: 29min 39s, total: 1h 21min 26s
# Wall time: 4h 4min 42s

# %%
import matplotlib.pyplot as plt

def visualize_density_map(pred_maps, gts, idx):
    n = pred_maps.shape[0]
    _, axes = plt.subplots(n, 3, figsize=(15, 5 * n))

    for i in range(n):
        pred_map = pred_maps[i]
        gt = gts[i]
        pred_map = (pred_map - np.min(pred_map)) / (np.max(pred_map) - np.min(pred_map))
        gt = (gt - np.min(gt)) / (np.max(gt) - np.min(gt))
        diff = pred_map - gt
        axes[i, 0].imshow(pred_map, cmap='jet', interpolation='nearest')
        axes[i, 0].set_title(f'Density Map Prediction')
        axes[i, 1].imshow(gt, cmap='jet', interpolation='nearest')
        axes[i, 1].set_title(f'Density Map Ground Truth')
        axes[i, 2].imshow(diff, cmap='jet', interpolation='nearest')
        axes[i, 2].set_title(f'Difference')

    plt.tight_layout()
    plt.show()

def test(net, test_loader, device, log_para):
    net.eval()
    gt_cnt_lis = []
    pred_cnt_lis = []
    visual_iter_idx_lis = [0]
    with torch.no_grad():
        for idx, (inputs, gt) in enumerate(test_loader):
            inputs, gt = inputs.to(device), gt.to(device)
            pred_map = net(inputs).squeeze()

            gt = gt.data.cpu().numpy()
            pred_map = pred_map.data.cpu().numpy()
            if idx in visual_iter_idx_lis:
                visualize_density_map(pred_map, gt, idx)
            for i in range(gt.shape[0]):
                gt_cnt = np.sum(gt[i]) / log_para
                pred_cnt = np.sum(pred_map[i]) / log_para
                gt_cnt_lis.append(float(gt_cnt))
                pred_cnt_lis.append(float(pred_cnt))

    y_true = np.array(gt_cnt_lis)
    y_pred = np.array(pred_cnt_lis)
    rmse = np.sqrt(np.mean((y_true - y_pred)**2)) 
    mae = np.mean(np.abs(y_true - y_pred))
    return rmse, mae

# %% [markdown]
# ### 模型测试

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = CSRNet().to(device)
net.load_state_dict(torch.load(f'{net.__class__.__name__}_best_model.pth'))
test_loader, log_para, restore_transform = get_data_loader('./dataset', batch_size=8, mode='test')
test_rmse, test_mae = test(net, test_loader, device, log_para)
print(f'Test RMSE: {test_rmse:.4f}, Test MAE: {test_mae:.4f}')
# Out:
# Test RMSE: 17.8763, Test MAE: 11.9340
